# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinFrancis11/py_wc_tool/blob/main/cc_wc_tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open("test.txt", "r")
text = file.read()
file.close()

encoded_bytes = text.encode("utf-8")

print(text)

byte_count = len(text.encode("utf-8"))

print(byte_count)
# Out:
# Hello world
# linux is powerfull
# Testing wc tools
#
# 49
